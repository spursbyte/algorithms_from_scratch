# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread,imshow

# %%
image = imread('test_img.jpg',as_gray=True)

# %%
imshow(image)

# %%
image.shape
# Out:
# (1000, 1000)

# %%
features=np.reshape(image,(1000*1000))

# %%
features.shape
# Out:
# (1000000,)

# %%
image_2=imread("test_img.jpg")
image_2.shape
# Out:
# (1000, 1000, 3)

# %%
feature_2=np.zeros((1000,1000))

# %%
for i in range(0,image_2.shape[0]):
    for j in range(0,image_2.shape[1]):
        feature_2[i][j]=((int(image_2[i,j,0]))+(int(image_2[i,j,1]))+(int(image_2[i,j,2])))
features_2_new=np.reshape(feature_2,(1000*1000))

# %%
features_2_new
# Out:
# array([204., 208., 213., ..., 110., 110., 107.])

# %%
from skimage.filters import prewitt_v,prewitt_h
image_3=imread('test_img.jpg',as_gray=True)
ed_pre_hor=prewitt_h(image_3)
ed_pre_ver=prewitt_v(image_3)

# %%
ed_pre_ver
# Out:
# array([[ 0.00514706,  0.00982026,  0.00353438, ..., -0.00589373,
#         -0.00130719,  0.        ],
#        [ 0.00308824,  0.00542484, -0.00010941, ..., -0.00589373,
#         -0.00196458,  0.        ],
#        [ 0.00140144,  0.00140144, -0.00337359, ..., -0.00392915,
#         -0.00196458,  0.        ],
#        ...,
#        [-0.00130719,  0.00130719,  0.00392157, ..., -0.02361869,
#          0.00522876,  0.01045752],
#        [-0.00784314, -0.00915033,  0.00653595, ..., -0.00896183,
#          0.00261438,  0.00392157],
#        [-0.0130719 , -0.01830065,  0.00522876, ..., -0.00130719,
#         -0.00130719, -0.00130719]])

# %%
imshow(ed_pre_ver,cmap='gray')

# %%
imshow(ed_pre_hor,cmap='gray')
